# %%
from PIL import Image
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'D:\tesseractOCR\tesseract.exe'
import matplotlib.pyplot as plt
# 画像ファイルを読み込み、表示する

# %%
pytesseract.get_languages(config='')
# Out:
# ['eng', 'enm', 'jpn', 'jpn_vert', 'osd']

# %%
img = Image.open('OIP.jpg')

plt.imshow(img)
text = pytesseract.image_to_string(img,lang='enm')
print(text)
# Out:
# b+ Vb? — .
#
# p= lt VO fac br = 4ac G@=b+¢C
# , 20
# n-
# . 1 k 1
# lim # (4) = [ poe
# NON TA n 0
# sin(a + 8) =sinacos B + cos asin B
# F=ma PV=nRT ‘Na
# 2 2 2
#
# pate Tu, du_ou
#
# Oo dx dy? dz?

# %%
import cv2
img_name = 'test.jpg'
img = cv2.imread(img_name)
d = pytesseract.image_to_data(img, output_type=pytesseract.Output.DICT)
n_boxes = len(d['level'])
for i in range(n_boxes):
    (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
plt.imshow(img)
